# %% [markdown]
# # Analysing Stack Overflow Annual Developer Survey
#
# ## Introduction
# For a developer, it is important to stay up to date with the new technologies as well as the most used languages and contributes to the open source community. In this project, we will analyze the data from Stack Overflow Annual Developer Survey to find out the most popular programming languages, databases, platforms, and other tools. We will also find out the most used languages and tools in different countries.

# %% [markdown]
# ## Dataset description
#
# In our database, it represents multiple programming languages, databases and tools that has been used throughout the year of 2022 in one of the most famous plateforms for developers, Stack Overflow. The data is collected from the annual survey that Stack Overflow conducts every year. The survey is conducted to get the insights of the developers and their preferences, it is conducted in the month of January and the results are published in the month of May, in 170 countries and 56 languages, has 65 questions and the data is collected from 64,000 developers.
#
# We'll also compare it to the data from the previous years 2020 and 2021 to see how the preferences have changed.
#
# Example of the survey:

# %%
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size
    
  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)
  
PDF('so_survey_2022.pdf', size=(800, 600))
# Out:
# \includegraphics[width=1.0\textwidth]{so_survey_2022.pdf}

# %%
import pandas as pd

df = pd.read_csv('survey_results_public.csv')
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# <p>As seen above, we have multiple columns in our dataset, each column represents a different question that was asked in the survey. The questions are related to the programming languages, databases, platforms, and tools that the developers use, as well as some informations about themselves. The data is collected from the developers from all over the world, and the developers are asked to provide their degree of studies, gender and work status.
#
# Using this dataset, we could analyse the different features and their caracteristics, the correlation between them, and try to predict which language would be used more in the future or which languages are going to be less used. We could also try to predict the salary of a developer based on the languages and tools that he uses, the country of a developer based on the languages and tools that he uses, the age of a developer based on the languages and tools that he uses. and many more variables.</p>

# %%
df[df['Country'] == 'Morocco']
# Out:
#        ResponseId                      MainBranch  \
# 1579         1580  I am a developer by profession
# 2120         2121  I am a developer by profession
# 2651         2652           I am learning to code
# 2666         2667  I am a developer by profession
# 2745         2746           I am learning to code
# ...           ...                             ...
# 71739       71740  I am a developer by profession
# 71925       71926  I am a developer by profession
# 72047       72048     I code primarily as a hobby
# 72330       72331  I am a developer by profession
# 73242       73243           I am learning to code
#
#                                               Employment  \
# 1579                                 Employed, full-time
# 2120   Independent contractor, freelancer, or self-em...
# 2651                                  Student, full-time
# 2666                                 Employed, full-time
# 2745                  Not employed, but looking for work
# ...                                                  ...
# 71739                                Employed, full-time
# 71925  Independent contractor, freelancer, or self-em...
# 72047                 Not employed, but looking for work
# 72330  Student, full-time;Not employed, but looking f...
# 73242                                 Student, full-time
#
#                                  RemoteWork  \
# 1579   Hybrid (some remote, some in-person)
# 2120                           Fully remote
# 2651                                    NaN
# 2666   Hybrid (some remote, some in-person)
# 2745                                    NaN
# ...                                     ...
# 71739                        Full in-person
# 71925                          Fully remote
# 72047                                   NaN
# 72330                                   NaN
# 73242                                   NaN
#
#                                         CodingActivities  \
# 1579                      Hobby;Bootstrapping a business
# 2120                                               Hobby
# 2651                                                 NaN
# 2666   Hobby;Bootstrapping a business;School or acade...
# 2745                                                 NaN
# ...                                                  ...
# 71739  Hobby;Bootstrapping a business;Freelance/contr...
# 71925  Contribute to open-source projects;Freelance/c...
# 72047                                                NaN
# 72330                                                NaN
# 73242                                                NaN
#
#                                                  EdLevel  \
# 1579     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2120     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2651   Secondary school (e.g. American high school, G...
# 2666     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2745        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 71739    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 71925       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72047    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72330       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73242                Associate degree (A.A., A.S., etc.)
#
#                                                LearnCode  \
# 1579   Books / Physical media;School (i.e., Universit...
# 2120   Books / Physical media;Other online resources ...
# 2651   Books / Physical media;Other online resources ...
# 2666   Other online resources (e.g., videos, blogs, f...
# 2745   Books / Physical media;Other online resources ...
# ...                                                  ...
# 71739  Books / Physical media;School (i.e., Universit...
# 71925  Books / Physical media;Other online resources ...
# 72047  Books / Physical media;Online Courses or Certi...
# 72330  Other online resources (e.g., videos, blogs, f...
# 73242  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  \
# 1579                                                 NaN
# 2120   Technical documentation;Blogs;Written Tutorial...
# 2651   Technical documentation;Blogs;Stack Overflow;V...
# 2666   Technical documentation;Blogs;Stack Overflow;O...
# 2745   Technical documentation;Programming Games;Onli...
# ...                                                  ...
# 71739                                                NaN
# 71925  Blogs;Programming Games;Stack Overflow;Video-b...
# 72047                                                NaN
# 72330  Blogs;Written Tutorials;Stack Overflow;Online ...
# 73242  Technical documentation;Blogs;Stack Overflow;V...
#
#                       LearnCodeCoursesCert         YearsCode  ...  \
# 1579                                   NaN                12  ...
# 2120    Coursera;Udemy;Pluralsight;Udacity                 8  ...
# 2651                                   NaN                 2  ...
# 2666   Coursera;Udemy;Codecademy;Skillsoft                 6  ...
# 2745                            Codecademy  Less than 1 year  ...
# ...                                    ...               ...  ...
# 71739                                Other                 6  ...
# 71925                                Udemy                 4  ...
# 72047                                Udemy                 3  ...
# 72330                                  NaN                 4  ...
# 73242                       Coursera;Other                 2  ...
#
#                     TimeSearching               TimeAnswering      Onboarding  \
# 1579          30-60 minutes a day         15-30 minutes a day   Somewhat long
# 2120         60-120 minutes a day         30-60 minutes a day       Very long
# 2651                          NaN                         NaN             NaN
# 2666   Less than 15 minutes a day  Less than 15 minutes a day  Somewhat short
# 2745                          NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 71739         15-30 minutes a day         15-30 minutes a day       Very long
# 71925                         NaN                         NaN             NaN
# 72047                         NaN                         NaN             NaN
# 72330                         NaN                         NaN             NaN
# 73242                         NaN                         NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 1579                                       Microservices         Yes
# 2120   Microservices;Continuous integration (CI) and ...         Yes
# 2651                                                 NaN         NaN
# 2666   DevOps function;Continuous integration (CI) an...         Yes
# 2745                                                 NaN         NaN
# ...                                                  ...         ...
# 71739                                      None of these         Yes
# 71925                                                NaN         NaN
# 72047                                                NaN         NaN
# 72330                                                NaN         NaN
# 73242                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 1579           No         Yes  Appropriate in length
# 2120          Yes         Yes  Appropriate in length
# 2651          NaN         NaN  Appropriate in length
# 2666          Yes         Yes               Too long
# 2745          NaN         NaN  Appropriate in length
# ...           ...         ...                    ...
# 71739          No         Yes  Appropriate in length
# 71925         NaN         NaN  Appropriate in length
# 72047         NaN         NaN  Appropriate in length
# 72330         NaN         NaN  Appropriate in length
# 73242         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 1579   Neither easy nor difficult             26484.0
# 2120                         Easy             90264.0
# 2651                         Easy                 NaN
# 2666                         Easy             14448.0
# 2745                         Easy                 NaN
# ...                           ...                 ...
# 71739                        Easy             20460.0
# 71925                        Easy                 NaN
# 72047  Neither easy nor difficult                 NaN
# 72330  Neither easy nor difficult                 NaN
# 73242                        Easy                 NaN
#
# [226 rows x 79 columns]

# %%
df_2021 = pd.read_csv('survey_results_public_2021.csv')
df_2021.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode  ...  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# 1  Other online resources (ex: videos, blogs, etc...         7  ...
# 2  Other online resources (ex: videos, blogs, etc...       NaN  ...
# 3                                                NaN       NaN  ...
# 4                            Friend or family member        17  ...
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#   ConvertedCompYearly
# 0             62268.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 48 columns]

# %%
df_2021[df_2021['Country'] == 'Morocco']
# Out:
#        ResponseId                                         MainBranch  \
# 221           222             I am a student who is learning to code
# 905           906                     I am a developer by profession
# 1058         1059                     I am a developer by profession
# 1232         1233                        I code primarily as a hobby
# 1681         1682                     I am a developer by profession
# ...           ...                                                ...
# 79917       79918                     I am a developer by profession
# 80615       80616                        I code primarily as a hobby
# 82306       82307  I used to be a developer by profession, but no...
# 82565       82566                        I code primarily as a hobby
# 83154       83155             I am a student who is learning to code
#
#                                               Employment  Country US_State  \
# 221                   Not employed, but looking for work  Morocco      NaN
# 905                                   Student, part-time  Morocco      NaN
# 1058                                  Employed full-time  Morocco      NaN
# 1232                  Not employed, but looking for work  Morocco      NaN
# 1681                                  Employed full-time  Morocco      NaN
# ...                                                  ...      ...      ...
# 79917                 Not employed, but looking for work  Morocco      NaN
# 80615                 Not employed, but looking for work  Morocco      NaN
# 82306  Independent contractor, freelancer, or self-em...  Morocco      NaN
# 82565  Independent contractor, freelancer, or self-em...  Morocco      NaN
# 83154                                 Student, full-time  Morocco      NaN
#
#       UK_Country                                            EdLevel  \
# 221          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 905          NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1058         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1232         NaN  Some college/university study without earning ...
# 1681         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 79917        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 80615        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82306        NaN                Associate degree (A.A., A.S., etc.)
# 82565        NaN  Some college/university study without earning ...
# 83154        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                  Age1stCode  \
# 221           25 - 34 years
# 905           18 - 24 years
# 1058          18 - 24 years
# 1232          18 - 24 years
# 1681          18 - 24 years
# ...                     ...
# 79917         11 - 17 years
# 80615          5 - 10 years
# 82306         18 - 24 years
# 82565  Younger than 5 years
# 83154         18 - 24 years
#
#                                                LearnCode YearsCode  ...  \
# 221      Other online resources (ex: videos, blogs, etc)       NaN  ...
# 905    Other online resources (ex: videos, blogs, etc...         5  ...
# 1058    School;Online Courses or Certification;Colleague         6  ...
# 1232                     Online Courses or Certification         2  ...
# 1681   Other online resources (ex: videos, blogs, etc...        11  ...
# ...                                                  ...       ...  ...
# 79917  Other online resources (ex: videos, blogs, etc...         7  ...
# 80615  Coding Bootcamp;Other online resources (ex: vi...        10  ...
# 82306  Other online resources (ex: videos, blogs, etc...         2  ...
# 82565  Other online resources (ex: videos, blogs, etc...         3  ...
# 83154  Other online resources (ex: videos, blogs, etc...         3  ...
#
#                    Age                      Gender                   Trans  \
# 221    25-34 years old                         Man                      No
# 905    25-34 years old                         Man                      No
# 1058   25-34 years old                         Man                      No
# 1232   18-24 years old                         Man                      No
# 1681   25-34 years old                         Man                      No
# ...                ...                         ...                     ...
# 79917  25-34 years old                         Man                      No
# 80615  18-24 years old                         Man                      No
# 82306  18-24 years old                         Man                      No
# 82565  18-24 years old                         Man                      No
# 83154  18-24 years old  Man;Or, in your own words:  Or, in your own words:
#
#                       Sexuality                     Ethnicity  \
# 221     Straight / Heterosexual   Black or of African descent
# 905     Straight / Heterosexual                  I don't know
# 1058    Straight / Heterosexual   Black or of African descent
# 1232                        NaN                           NaN
# 1681    Straight / Heterosexual   Black or of African descent
# ...                         ...                           ...
# 79917   Straight / Heterosexual        Or, in your own words:
# 80615  Prefer to self-describe:  White or of European descent
# 82306   Straight / Heterosexual        Or, in your own words:
# 82565   Straight / Heterosexual                Middle Eastern
# 83154  Prefer to self-describe:        Hispanic or Latino/a/x
#
#            Accessibility                                       MentalHealth  \
# 221    None of the above                                  Prefer not to say
# 905    None of the above                                  None of the above
# 1058   None of the above                                  None of the above
# 1232                 NaN                                                NaN
# 1681   None of the above  I have a concentration and/or memory disorder ...
# ...                  ...                                                ...
# 79917  None of the above  I have a mood or emotional disorder (e.g. depr...
# 80615  None of the above                                  None of the above
# 82306  None of the above                                  None of the above
# 82565  None of the above                         I have an anxiety disorder
# 83154  None of the above                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 221    Appropriate in length  Neither easy nor difficult                 NaN
# 905    Appropriate in length                        Easy                 NaN
# 1058   Appropriate in length  Neither easy nor difficult                 NaN
# 1232                Too long                        Easy                 NaN
# 1681                     NaN  Neither easy nor difficult             12324.0
# ...                      ...                         ...                 ...
# 79917  Appropriate in length                        Easy                 NaN
# 80615  Appropriate in length  Neither easy nor difficult                 NaN
# 82306  Appropriate in length  Neither easy nor difficult                 NaN
# 82565               Too long  Neither easy nor difficult                 NaN
# 83154               Too long  Neither easy nor difficult                 NaN
#
# [204 rows x 48 columns]

# %%
df_2020 = pd.read_csv('survey_results_public_2020.csv')
df_2020.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
df_2020[df_2020['Country'] == 'Morocco']
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 571           573          I am a developer by profession      Yes  26.0
# 839           841          I am a developer by profession      Yes  28.0
# 1712         1721          I am a developer by profession      Yes   NaN
# 3430         3444  I am a student who is learning to code      Yes  21.0
# 3577         3591             I code primarily as a hobby      Yes  20.0
# ...           ...                                     ...      ...   ...
# 64022       65486  I am a student who is learning to code      Yes   NaN
# 64315       39520                                     NaN      Yes   NaN
# 64438       62391                                     NaN      Yes   NaN
# 64454       64480                                     NaN      Yes   NaN
# 64457       64867                                     NaN      Yes   NaN
#
#                  Age1stCode CompFreq  CompTotal  ConvertedComp  Country  \
# 571                      15  Monthly     6700.0         8256.0  Morocco
# 839                      18  Monthly    17300.0        21312.0  Morocco
# 1712                     18      NaN        NaN            NaN  Morocco
# 3430                     18      NaN        NaN            NaN  Morocco
# 3577                     10      NaN        NaN            NaN  Morocco
# ...                     ...      ...        ...            ...      ...
# 64022                   NaN      NaN        NaN            NaN  Morocco
# 64315                   NaN      NaN        NaN            NaN  Morocco
# 64438  Younger than 5 years      NaN        NaN            NaN  Morocco
# 64454                    21      NaN        NaN            NaN  Morocco
# 64457                   NaN      NaN        NaN            NaN  Morocco
#
#           CurrencyDesc  ...                  SurveyEase  \
# 571    Moroccan dirham  ...                        Easy
# 839    Moroccan dirham  ...                        Easy
# 1712   Moroccan dirham  ...  Neither easy nor difficult
# 3430               NaN  ...                        Easy
# 3577               NaN  ...  Neither easy nor difficult
# ...                ...  ...                         ...
# 64022              NaN  ...                         NaN
# 64315              NaN  ...                         NaN
# 64438              NaN  ...  Neither easy nor difficult
# 64454              NaN  ...                         NaN
# 64457              NaN  ...                         NaN
#
#                 SurveyLength Trans  \
# 571    Appropriate in length    No
# 839    Appropriate in length    No
# 1712   Appropriate in length    No
# 3430   Appropriate in length   NaN
# 3577   Appropriate in length    No
# ...                      ...   ...
# 64022                    NaN   NaN
# 64315                    NaN   NaN
# 64438              Too short   NaN
# 64454                    NaN   NaN
# 64457                    NaN   NaN
#
#                                           UndergradMajor  \
# 571    Computer science, computer engineering, or sof...
# 839    Computer science, computer engineering, or sof...
# 1712   Computer science, computer engineering, or sof...
# 3430   Computer science, computer engineering, or sof...
# 3577                       Web development or web design
# ...                                                  ...
# 64022                                                NaN
# 64315                                                NaN
# 64438                                                NaN
# 64454                                                NaN
# 64457                                                NaN
#
#                                 WebframeDesireNextYear  \
# 571    Angular;Express;Laravel;React.js;Symfony;Vue.js
# 839                            Angular;ASP.NET;Laravel
# 1712                               Django;Flask;Vue.js
# 3430             Express;Gatsby;React.js;Ruby on Rails
# 3577                                            jQuery
# ...                                                ...
# 64022                                              NaN
# 64315                                              NaN
# 64438        Angular.js;Express;React.js;Ruby on Rails
# 64454                                              NaN
# 64457                                              NaN
#
#                               WebframeWorkedWith  \
# 571                               jQuery;Laravel
# 839               Angular;ASP.NET;Laravel;Spring
# 1712                         Flask;jQuery;Vue.js
# 3430                            Express;React.js
# 3577                                      jQuery
# ...                                          ...
# 64022                                        NaN
# 64315                                        NaN
# 64438  Angular.js;Express;React.js;Ruby on Rails
# 64454                                        NaN
# 64457                                        NaN
#
#                                            WelcomeChange WorkWeekHrs  \
# 571              Just as welcome now as I felt last year        44.0
# 839             Somewhat less welcome now than last year        40.0
# 1712             Just as welcome now as I felt last year        38.0
# 3430             Just as welcome now as I felt last year         NaN
# 3577   Not applicable - I did not use Stack Overflow ...         NaN
# ...                                                  ...         ...
# 64022                                                NaN         NaN
# 64315  Not applicable - I did not use Stack Overflow ...         NaN
# 64438                                                NaN         NaN
# 64454            Just as welcome now as I felt last year         NaN
# 64457                                                NaN         NaN
#
#               YearsCode      YearsCodePro
# 571                   8                 5
# 839                  11                 6
# 1712                 10                 6
# 3430                  3               NaN
# 3577                 10               NaN
# ...                 ...               ...
# 64022               NaN               NaN
# 64315               NaN               NaN
# 64438  Less than 1 year  Less than 1 year
# 64454                 3               NaN
# 64457               NaN               NaN
#
# [176 rows x 61 columns]
